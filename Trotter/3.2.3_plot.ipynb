# %%
import tensorcircuit as tc
import tensorflow as ts 
import numpy as np
import math
from numpy import linalg as LA
from matplotlib import pyplot as plt
K = tc.set_backend("tensorflow")
tc.set_dtype("complex128")

sim_t = math.pi * 5
interval = 10000
dt = sim_t / interval
cur_t = 0 
h_m = 1

qubit = 2
min_w = 999
w=0
v=0
I = tc.gates._i_matrix
X = tc.gates._x_matrix  
Y = tc.gates._y_matrix  
Z = tc.gates._z_matrix

# %%
def i_iterate_multiplication(u):
    tmp = 1
    for i in range(u):
        tmp = np.kron(I, tmp)
    return tmp

def zzi(i):
     return np.kron(np.kron(i_iterate_multiplication(i), np.kron(Z, Z)), i_iterate_multiplication(qubit-2-i))
def xi(i):
    return np.kron(np.kron(i_iterate_multiplication(i), X), i_iterate_multiplication(qubit-1-i))
def zi(i):
    return np.kron(np.kron(i_iterate_multiplication(i), Z), i_iterate_multiplication(qubit-1-i))

h_Z = 0
h_ZZ = 0
h_X = 0
for i in range(qubit):
    h_Z = h_Z + zi(i)
for i in range(qubit-1):
    h_ZZ = h_ZZ - zzi(i)
for i in range(qubit):
    h_X = h_X + h_m * xi(i)
def evolution(h, t):
    return tc.gates.exponential_gate(h, t)

# %%
#w, v = LA.eig(H)
#for i in range(0, len(w)):
#        if w[i] < min_w:
#            min_w = w[i]

c_precise = tc.Circuit(qubit)
c_trotter = tc.Circuit(qubit)
state_precise = c_precise.state()
state_trotter = c_trotter.state()
cnt=0;
zt=[0 for i in range(10000)]
zp=[0 for i in range(10000)]
time=[0 for i in range(10000)]

for _interval in range(interval):
    if(_interval % 100 == 0):
        print(_interval)
    c_precise = tc.Circuit(qubit, inputs = state_precise)
    c_trotter = tc.Circuit(qubit, inputs = state_trotter)
    c_trotter.any(*range(qubit), unitary=evolution(h_X, dt))
    c_trotter.any(*range(qubit), unitary=evolution(h_ZZ, dt))
    cur_t += dt
    c_precise.any(*range(qubit), unitary=evolution(h_X + h_ZZ, dt))
    zt[cnt]+=c_trotter.expectation((h_Z, [*range(qubit)]))
    zp[cnt]+=c_precise.expectation((h_Z, [*range(qubit)]))
    time[cnt]=cur_t
    cnt+=1
    state_precise = c_precise.state()
    state_trotter = c_trotter.state()
print(zt)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# [<tf.Tensor: shape=(), dtype=complex128, numpy=(1.9999901304032852+2.1260974826726277e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.999960521807956-3.379350155713993e-20j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9999111747984608+4.217556907129548e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9998420903488638-6.415459596669574e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9997532698228209+4.544328729121872e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9996447149735468-7.874105658441734e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.999516427943771+9.74454034915607e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.999368411265685-1.0299067943367749e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.999200667860882-9.627835807111518e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9990132010402797-7.529347831932197e-21j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9988060145040443+1.5456438096109993e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.998579112341495-2.6419232876633254e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.998332499031007-1.4842704916116778e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9980661794398955+3.91044047100515e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9977801588243023-2.093412467270074e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9974744428290603+2.596110570394555e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9971490374875585-1.3170404815582384e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9968039492215894+6.81333646976019e-20j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9964391848411935+1.3689485077500344e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.99605475154449-4.515370498187789e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9956506569174992-6.2473977657654155e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9952269089339565+1.4777191990435669e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.994783515955114-2.75414610771738e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9943204867295345+6.749758093884697e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9938378303928768+8.378134906020694e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9933355564676691+5.573464388564121e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9928136748630751-5.620520750131423e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9922721958746485+4.360854473095735e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.99171113018408+3.5058387615790454e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9911304888589314+5.6979902183427775e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9905302833523677-2.2912968030199003e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9899105255028686-1.738664441284e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.989271227533941+2.0152857476660795e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9886124020538136+1.61895184374636e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9879340620551291-6.69620705363955e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9872362209146217+2.855910677972951e-20j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9865188923927886+4.352081826764315e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9857820906335486+4.927047912137851e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9850258301638959-8.555316884224836e-19j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9842501258935383+4.7315352256033625e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9834549931145335+1.031650766789756e-17j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.982640447500907-3.5847798620714965e-18j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1.9818065051082698-1.2020136064568934e-17j)>, <tf.Tensor: shape=(), dtype=complex128, numpy=(1. ...

# %%
plt.plot([time[i] for i in range(interval)], [zt[i] for i in range(interval)])
plt.plot([time[i] for i in range(interval)], [zp[i] for i in range(interval)])
plt.show()
