# %%
from numpy import linalg as LA
from functools import partial
import numpy as np
import tensorflow as tf
import tensorcircuit as tc
import math
import matplotlib.pyplot as plt

plt.plot([0.1*i for i in range(40)], np.loadtxt('n8l2_s_h.txt'), label = "Optimized Approximation")
plt.plot([0.1*i for i in range(40)], np.loadtxt('n8l2_s_w.txt'), label = "Minimum Egenvalue")
plt.legend()

# %%
plt.plot([0.1*i for i in range(40)], np.loadtxt('n8l2_s_loss.txt'), label = "Loss")
plt.legend()
